# %%
import nltk
import json
import spacy
import re, urllib, json
from bs4 import BeautifulSoup
import time
from collections import Counter

# %%
word = 'many cat'

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk import FreqDist
from nltk import ngrams

# %%
text = ''
for p in para:
    text += p + ' '

# %%
bigrm = list(nltk.bigrams(text.split()))

# %%
bi_count = dict(Counter(bigrm))

# %%
bi_count
# Out:
# {('The', 'Normans'): 8,
#  ('Normans', '(Norman:'): 1,
#  ('(Norman:', 'Nourmands;'): 1,
#  ('Nourmands;', 'French:'): 1,
#  ('French:', 'Normands;'): 1,
#  ('Normands;', 'Latin:'): 1,
#  ('Latin:', 'Normanni)'): 1,
#  ('Normanni)', 'were'): 1,
#  ('were', 'the'): 10,
#  ('the', 'people'): 7,
#  ('people', 'who'): 6,
#  ('who', 'in'): 3,
#  ('in', 'the'): 1050,
#  ('the', '10th'): 6,
#  ('10th', 'and'): 2,
#  ('and', '11th'): 1,
#  ('11th', 'centuries'): 1,
#  ('centuries', 'gave'): 1,
#  ('gave', 'their'): 1,
#  ('their', 'name'): 2,
#  ('name', 'to'): 5,
#  ('to', 'Normandy,'): 1,
#  ('Normandy,', 'a'): 1,
#  ('a', 'region'): 1,
#  ('region', 'in'): 5,
#  ('in', 'France.'): 4,
#  ('France.', 'They'): 1,
#  ('They', 'were'): 10,
#  ('were', 'descended'): 4,
#  ('descended', 'from'): 6,
#  ('from', 'Norse'): 1,
#  ('Norse', '("Norman"'): 1,
#  ('("Norman"', 'comes'): 1,
#  ('comes', 'from'): 6,
#  ('from', '"Norseman")'): 1,
#  ('"Norseman")', 'raiders'): 1,
#  ('raiders', 'and'): 1,
#  ('and', 'pirates'): 1,
#  ('pirates', 'from'): 1,
#  ('from', 'Denmark,'): 1,
#  ('Denmark,', 'Iceland'): 1,
#  ('Iceland', 'and'): 1,
#  ('and', 'Norway'): 3,
#  ('Norway', 'who,'): 1,
#  ('who,', 'under'): 1,
#  ('under', 'their'): 4,
#  ('their', 'leader'): 1,
#  ('leader', 'Rollo,'): 1,
#  ('Rollo,', 'agreed'): 1,
#  ('agreed', 'to'): 10,
#  ('to', 'swear'): 1,
#  ('swear', 'fealty'): 1,
#  ('fealty', 'to'): 1,
#  ('to', 'King'): 1,
#  ('King', 'Charles'): 2,
#  ('Charles', 'III'): 2,
#  ('III', 'of'): 5,
#  ('of', 'West'): 4,
#  ('West', 'Francia.'): 2,
#  ('Francia.', 'Through'): 1,
#  ('Through', 'generations'): 1,
#  ('generations', 'of'): 1,
#  ('of', 'assimilation'): 1,
#  ('assimilation', 'and'): 1,
#  ('and', 'mixing'): 1,
#  ('mixing', 'with'): 1,
#  ('with', 'the'): 193,
#  ('the', 'native'): 2,
#  ('native', 'Frankish'): 1,
#  ('Frankish', 'and'): 1,
#  ('and', 'Roman-Gaulish'): 1,
#  ('Roman-Gaulish', 'populations,'): 1,
#  ('populations,', 'their'): 1,
#  ('their', 'descendants'): 4,
#  ('descendants', 'would'): 1,
#  ('would', 'gradually'): 1,
#  ('gradually', 'merge'): 1,
#  ('merge', 'with'): 1,
#  ('the', 'Carolingian-based'): 1,
#  ('Carolingian-based', 'cultures'): 1,
#  ('cultures', 'of'): 2,
#  ('Francia.', 'The'): 1,
#  ('The', 'distinct'): 1,
#  ('distinct', 'cultural'): 1,
#  ('cultural', 'and'): 6,
#  ('and', 'ethnic'): 1,
#  ('ethnic', 'identity'): 1,
#  ('identity', 'of'): 2,
#  ('of', 'the'): 1809,
#  ('the', 'Normans'): 15,
#  ('Normans', 'emerged'): 1,
#  ('emerged', 'initially'): 1,
#  ('initially', 'in'): 1,
#  ('the', 'first'): 100,
#  ('first', 'half'): 5,
#  ('half', 'of'): 19,
#  ('10th', 'century,'): 4,
#  ('century,', 'and'): 2,
#  ('and', 'it'): 21,
#  ('it', 'continued'): 2,
#  ('continued', 'to'): 13,
#  ('to', 'evolve'): 2,
#  ('evolve', 'over'): 1,
#  ('over', 'the'): 45,
#  ('the', 'succeeding'): 1,
#  ('succeeding', 'centuries.'): 1,
#  ('centuries.', 'The'): 1,
#  ('The', 'Norman'): 2,
#  ('Norman', 'dynasty'): 1,
#  ('dynasty', 'had'): 2,
#  ('had', 'a'): 25,
#  ('a', 'major'): 31,
#  ('major', 'political,'): 1,
#  ('political,', 'cultural'): 1,
#  ('and', 'military'): 10,
#  ('military', 'impact'): 1,
#  ('impact', 'on'): 7,
#  ('on', 'medieval'): 1,
#  ('medieval', 'Europe'): 2,
#  ('Europe', 'and'): 5,
#  ('and', 'even'): 13,
#  ('even', 'the'): 2,
#  ('the', 'Near'): 2,
#  ('Near', 'East.'): 1,
#  ('East.', 'The'): 3,
#  ('Normans', 'were'): 3,
#  ('were', 'famed'): 1,
#  ('famed', 'for'): 2,
#  ('for', 'their'): 29,
#  ('their', 'martial'): 1,
#  ('martial', 'spirit'): 1,
#  ('spirit', 'and'): 1,
#  ('and', 'eventually'): 6,
#  ('eventually', 'for'): 1,
#  ('their', 'Christian'): 1,
#  ('Christian', 'piety,'): 1,
#  ('piety,', 'becoming'): 1,
#  ('becoming', 'exponents'): 1,
#  ('exponents', 'of'): 1,
#  ('the', 'Catholic'): 6,
#  ('Catholic', 'orthodoxy'): 1,
#  ('orthodoxy', 'into'): 1,
#  ('into', 'which'): 2,
#  ('which', 'they'): 19,
#  ('they', 'assimilated.'): 1,
#  ('assimilated.', 'They'): 1,
#  ('They', 'adopted'): 1,
#  ('adopted', 'the'): 4,
#  ('the', 'Gallo-Romance'): 2,
#  ('Gallo-Romance', 'language'): 2,
#  ('language', 'of'): 4,
#  ('the', 'Frankish'): 1,
#  ('Frankish', 'land'): 1,
#  ('land', 'they'): 1,
#  ('they', 'settled,'): 1,
#  ('settled,', 'their'): 1,
#  ('their', 'dialect'): 1,
#  ('dialect', 'becoming'): 1,
#  ('becoming', 'known'): 2,
#  ('known', 'as'): 89,
#  ('as', 'Norman,'): 1,
#  ('Norman,', 'Normaund'): 1,
#  ('Normaund', 'or'): 1,
#  ('or', 'Norman'): 1,
#  ('Norman', 'French,'): 1,
#  ('French,', 'an'): 1,
#  ('an', 'important'): 20,
#  ('important', 'literary'): 1,
#  ('literary', 'language.'): 1,
#  ('language.', 'The'): 3,
#  ('The', 'Duchy'): 2,
#  ('Duchy', 'of'): 6,
#  ('of', 'Normandy,'): 6,
#  ('Normandy,', 'which'): 2,
#  ('they', 'formed'): 1,
#  ('formed', 'by'): 2,
#  ('by', 'treaty'): 1,
#  ('treaty', 'with'): 2,
#  ('the', 'French'): 65,
#  ('French', 'crown,'): 1,
#  ('crown,', 'was'): 1,
#  ('was', 'a'): 65,
#  ('a', 'great'): 7,
#  ('great', 'fief'): 1,
#  ('fief', 'of'): 1,
#  ('of', 'medieval'): 1,
#  ('medieval', 'France,'): 1,
#  ('France,', 'and'): 6,
#  ('and', 'under'): 1,
#  ('under', 'Richard'): 1,
#  ('Richard', 'I'): 1,
#  ('I', 'of'): 3,
#  ('of', 'Normandy'): 4,
#  ('Normandy', 'was'): 3,
#  ('was', 'forged'): 2,
#  ('forged', 'into'): 1,
#  ('into', 'a'): 27,
#  ('a', 'cohesive'): 1,
#  ('cohesive', 'and'): 1,
#  ('and', 'formidable'): 1,
#  ('formidable', 'principality'): 1,
#  ('principality', 'in'): 2,
#  ('in', 'feudal'): 1,
#  ('feudal', 'tenure.'): 1,
#  ('tenure.', 'The'): 1,
#  ('Normans', 'are'): 1,
#  ('are', 'noted'): 1,
#  ('noted', 'both'): 1,
#  ('both', 'for'): 3,
#  ('their', 'culture,'): 1,
#  ('culture,', 'such'): 1,
#  ('such', 'as'): 243,
#  ('as', 'their'): 5,
#  ('their', 'unique'): 1,
#  ('unique', 'Romanesque'): 2,
#  ('Romanesque', 'architecture'): 1,
#  ('architecture', 'and'): 2,
#  ('and', 'musical'): 1,
#  ('musical', 'traditions,'): 1,
#  ('traditions,', 'and'): 1,
#  ('and', 'for'): 6,
#  ('their', 'significant'): 1,
#  ('significant', 'military'): 1,
#  ('military', 'accomplishments'): 1,
#  ('accomplishments', 'and'): 1,
#  ('and', 'innovations.'): 1,
#  ('innovations.', 'Norman'): 1,
#  ('Norman', 'adventurers'): 1,
#  ('adventurers', 'founded'): 1,
#  ('founded', 'the'): 6,
#  ('the', 'Kingdom'): 8,
#  ('Kingdom', 'of'): 10,
#  ('of', 'Sicily'): 1,
#  ('Sicily', 'under'): 1,
#  ('under', 'Roger'): 1,
#  ('Roger', 'II'): 1,
#  ('II', 'after'): 1,
#  ('after', 'conquering'): 1,
#  ('conquering', 'southern'): 1,
#  ('southern', 'Italy'): 2,
#  ('Italy', 'on'): 1,
#  ('on', 'the'): 291,
#  ('the', 'Saracens'): 1,
#  ('Saracens', 'and'): 1,
#  ('and', 'Byzantines,'): 1,
#  ('Byzantines,', 'and'): 1,
#  ('and', 'an'): 15,
#  ('an', 'expedition'): 5,
#  ('expedition', 'on'): 1,
#  ('on', 'behalf'): 3,
#  ('behalf', 'of'): 3,
#  ('of', 'their'): 57,
#  ('their', 'duke,'): 1,
#  ('duke,', 'William'): 1,
#  ('William', 'the'): 5,
#  ('the', 'Conqueror,'): 2,
#  ('Conqueror,', 'led'): 1,
#  ('led', 'to'): 31,
#  ('to', 'the'): 564,
#  ('the', 'Norman'): 6,
#  ('Norman', 'conquest'): 1,
#  ('conquest', 'of'): 9,
#  ('of', 'England'): 4,
#  ('England', 'at'): 1,
#  ('at', 'the'): 156,
#  ('the', 'Battle'): 11,
#  ('Battle', 'of'): 16,
#  ('of', 'Hastings'): 1,
#  ('Hastings', 'in'): 1,
#  ('in', '1066.'): 1,
#  ('1066.', 'Norman'): 1,
#  ('Norman', 'cultural'): 1,
#  ('military', 'influence'): 1,
#  ('influence', 'spread'): 1,
#  ('spread', 'from'): 2,
#  ('from', 'these'): 3,
#  ('these', 'new'): 1,
#  ('new', 'European'): 1,
#  ('European', 'centres'): 1,
#  ('centres', 'to'): 1,
#  ('the', 'Crusader'): 2,
#  ('Crusader', 'states'): 1,
#  ('states', 'of'): 4,
#  ('Near', 'East,'): 1,
#  ('East,', 'where'): 1,
#  ('where', 'their'): 5,
#  ('their', 'prince'): 1,
#  ('prince', 'Bohemond'): 1,
#  ('Bohemond', 'I'): 1,
#  ('I', 'founded'): 1,
#  ('the', 'Principality'): 1,
#  ('Principality', 'of'): 2,
#  ('of', 'Antioch'): 2,
#  ('Antioch', 'in'): 2,
#  ('the', 'Levant,'): 1,
#  ('Levant,', 'to'): 1,
#  ('to', 'Scotland'): 1,
#  ('Scotland', 'and'): 4,
#  ('and', 'Wales'): 1,
#  ('Wales', 'in'): 2,
#  ('in', 'Great'): 1,
#  ('Great', 'Britain,'): 1,
#  ('Britain,', 'to'): 2,
#  ('to', 'Ireland,'): 1,
#  ('Ireland,', 'and'): 1,
#  ('and', 'to'): 23,
#  ('the', 'coasts'): 1,
#  ('coasts', 'of'): 2,
#  ('of', 'north'): 2,
#  ('north', 'Africa'): 1,
#  ('Africa', 'and'): 6,
#  ('and', 'the'): 469,
#  ('the', 'Canary'): 3,
#  ('Canary', 'Islands.'): 1,
#  ('Islands.', 'The'): 1,
#  ('The', 'English'): 3,
#  ('English', 'name'): 1,
#  ('name', '"Normans"'): 1,
#  ('"Normans"', 'comes'): 1,
#  ('from', 'the'): 242,
#  ('French', 'words'): 1,
#  ('words', 'Normans/Normanz,'): 1,
#  ('Normans/Normanz,', 'plural'): 1,
#  ('plural', 'of'): 1,
#  ('of', 'Normant,'): 1,
#  ('Normant,', 'modern'): 1,
#  ('modern', 'French'): 1,
#  ('French', 'normand,'): 1,
#  ('normand,', 'which'): 1,
#  ('which', 'is'): 65,
#  ('is', 'itself'): 1,
#  ('itself', 'borrowed'): 1,
#  ('borrowed', 'from'): 1,
#  ('from', 'Old'): 2,
#  ('Old', 'Low'): 1,
#  ('Low', 'Franconian'): 1,
#  ('Franconian', 'Nortmann'): 1,
#  ('Nortmann', '"Northman"'): 1,
#  ('"Northman"', 'or'): 1,
#  ('or', 'directly'): 1,
#  ('directly', 'from'): 1,
#  ('Old', 'Norse'): 3,
#  ('Norse', 'Norðmaðr,'): 1,
#  ('Norðmaðr,', 'Latinized'): 1,
#  ('Latinized', 'variously'): 1,
#  ('variously', 'as'): 1,
#  ('as', 'Nortmannus,'): 1,
#  ('Nortmannus,', 'Normannus,'): 1,
#  ('Normannus,', 'or'): 1,
#  ('or', 'Nordmannus'): 1,
#  ('Nordmannus', '(recorded'): 1,
#  ('(recorded', 'in'): 1,
#  ('in', 'Medieval'): 1,
#  ('Medieval', 'Latin,'): 1,
#  ('Latin,', '9th'): 1,
#  ('9th', 'century)'): 1,
#  ('century)', 'to'): 1,
#  ('to', 'mean'): 3,
#  ('mean', '"Norseman,'): 1,
#  ('"Norseman,', 'Viking".'): 1,
#  ('Viking".', 'In'): 1,
#  ('In', 'the'): 108,
#  ('the', 'course'): 8,
#  ('course', 'of'): 9,
#  ('century,', 'the'): 6,
#  ('the', 'initially'): 1,
#  ('initially', 'destructive'): 1,
#  ('destructive', 'incursions'): 1,
#  ('incursions', 'of'): 1,
#  ('of', 'Norse'): 1,
#  ('Norse', 'war'): 1,
#  ('war', 'bands'): 1,
#  ('bands', 'into'): 1,
#  ('into', 'the'): 69,
#  ('the', 'rivers'): 1,
#  ('rivers', 'of'): 1,
#  ('of', 'France'): 5,
#  ('France', 'evolved'): 1,
#  ('evolved', 'into'): 5,
#  ('into', 'more'): 1,
#  ('more', 'permanent'): 2,
#  ('permanent', 'encampments'): 1,
#  ('encampments', 'that'): 1,
#  ('that', 'included'): 7,
#  ('included', 'local'): 1,
#  ('local', 'women'): 1,
#  ('women', 'and'): 2,
#  ('and', 'personal'): 1,
#  ('personal', 'property.'): 1,
#  ('property.', 'The'): 1,
#  ('which', 'began'): 2,
#  ('began', 'in'): 5,
#  ('in', '911'): 1,
#  ('911', 'as'): 1,
#  ('as', 'a'): 193,
#  ('a', 'fiefdom,'): 1,
#  ('fiefdom,', 'was'): 1,
#  ('was', 'established'): 20,
#  ('established', 'by'): 7,
#  ('by', 'the'): 307,
#  ('the', 'treaty'): 4,
#  ('treaty', 'of'): 1,
#  ('of', 'Saint-Clair-sur-Epte'): 1,
#  ('Saint-Clair-sur-Epte', 'between'): 1,
#  ('between', 'King'): 1,
#  ('West', 'Francia'): 1,
#  ('Francia', 'and'): 1,
#  ('the', 'famed'): 1,
#  ('famed', 'Viking'): 1,
#  ('Viking', 'ruler'): 1,
#  ('ruler', 'Rollo,'): 1,
#  ('Rollo,', 'and'): 1,
#  ('and', 'was'): 30,
#  ('was', 'situated'): 1,
#  ('situated', 'in'): 2,
#  ('the', 'former'): 16,
#  ('former', 'Frankish'): 1,
#  ('Frankish', 'kingdom'): 1,
#  ('kingdom', 'of'): 1,
#  ('of', 'Neustria.'): 1,
#  ('Neustria.', 'The'): 1,
#  ('The', 'treaty'): 3,
#  ('treaty', 'offered'): 1,
#  ('offered', 'Rollo'): 1,
#  ('Rollo', 'and'): 1,
#  ('and', 'his'): 22,
#  ('his', 'men'): 3,
#  ('men', 'the'): 1,
#  ('French', 'lands'): 1,
#  ('lands', 'between'): 1,
#  ('between', 'the'): 55,
#  ('the', 'river'): 18,
#  ('river', 'Epte'): 1,
#  ('Epte', 'and'): 1,
#  ('the', 'Atlantic'): 10,
#  ('Atlantic', 'coast'): 3,
#  ('coast', 'in'): 1,
#  ('in', 'exchange'): 4,
#  ('exchange', 'for'): 5,
#  ('their', 'protection'): 1,
#  ('protection', 'against'): 2,
#  ('against', 'further'): 1,
#  ('further', 'Viking'): 1,
#  ('Viking', 'incursions.'): 1,
#  ('incursions.', 'The'): 1,
#  ('The', 'area'): 5,
#  ('area', 'corresponded'): 1,
#  ('corresponded', 'to'): 1,
#  ('the', 'northern'): 12,
#  ('northern', 'part'): 3,
#  ('part', 'of'): 82,
#  ('of', 'present-day'): 9,
#  ('present-day', 'Upper'): 1,
#  ('Upper', 'Normandy'): 1,
#  ('Normandy', 'down'): 1,
#  ('down', 'to'): 7,
#  ('river', 'Seine,'): 1,
#  ('Seine,', 'but'): 1,
#  ('but', 'the'): 19,
#  ('the', 'Duchy'): 2,
#  ('Duchy', 'would'): 1,
#  ('would', 'eventually'): 2,
#  ('eventually', 'extend'): 1,
#  ('extend', 'west'): 1,
#  ('west', 'beyond'): 1,
#  ('beyond', 'the'): 5,
#  ('the', 'Seine.'): 1,
#  ('Seine.', 'The'): 1,
#  ('The', 'territory'): 1,
#  ('territory', 'was'): 3,
#  ('was', 'roughly'): 2,
#  ('roughly', 'equivalent'): 2,
#  ('equivalent', 'to'): 10,
#  ('the', 'old'): 8,
#  ('old', 'province'): 1,
#  ('province', 'of'): 4,
#  ('of', 'Rouen,'): 1,
#  ('Rouen,', 'and'): 1,
#  ('and', 'reproduced'): 1,
#  ('reproduced', 'the'): 1,
#  ('the', 'Roman'): 9,
#  ('Roman', 'administrative'): 1,
#  ('administrative', 'structure'): 2,
#  ('structure', 'of'): 6,
#  ('of', 'Gallia'): 1,
#  ('Gallia', 'Lugdunensis'): 1,
#  ('Lugdunensis', 'II'): 1,
#  ('II', '(part'): 1,
#  ('(part', 'of'): 1,
#  ('former', 'Gallia'): 1,
#  ('Gallia', 'Lugdunensis).'): 1,
#  ('Lugdunensis).', 'Before'): 1,
#  ('Before', "Rollo's"): 1,
#  ("Rollo's", 'arrival,'): 1,
#  ('arrival,', 'its'): 1,
#  ('its', 'populations'): 1,
#  ('populations', 'did'): 1,
#  ('did', 'not'): 41,
#  ('not', 'differ'): 1,
#  ('differ', 'from'): 2,
#  ('from', 'Picardy'): 1,
#  ('Picardy', 'or'): 1,
#  ('or', 'the'): 20,
#  ('the', 'Île-de-France,'): 1,
#  ('Île-de-France,', 'which'): 1,
#  ('which', 'were'): 13,
#  ('were', 'considered'): 4,
#  ('considered', '"Frankish".'): 1,
#  ('"Frankish".', 'Earlier'): 1,
#  ('Earlier', 'Viking'): 1,
#  ('Viking', 'settlers'): 1,
#  ('settlers', 'had'): 1,
#  ('had', 'begun'): 1,
#  ('begun', 'arriving'): 1,
#  ('arriving', 'in'): 1,
#  ('the', '880s,'): 1,
#  ('880s,', 'but'): 1,
#  ('but', 'were'): 6,
#  ('were', 'divided'): 2,
#  ('divided', 'between'): 2,
#  ('between', 'colonies'): 1,
#  ('colonies', 'in'): 5,
#  ('the', 'east'): 9,
#  ('east', '(Roumois'): 1,
#  ('(Roumois', 'and'): 1,
#  ('and', 'Pays'): 1,
#  ('Pays', 'de'): 1,
#  ('de', 'Caux)'): 1,
#  ('Caux)', 'around'): 1,
#  ('around', 'the'): 23,
#  ('the', 'low'): 4,
#  ('low', 'Seine'): 1,
#  ('Seine', 'valley'): 1,
#  ('valley', 'and'): 3,
#  ('and', 'in'): 46,
#  ('the', 'west'): 10,
#  ('west', 'in'): 1,
#  ('the', 'Cotentin'): 1,
#  ('Cotentin', 'Peninsula,'): 1,
#  ('Peninsula,', 'and'): 1,
#  ('and', 'were'): 13,
#  ('were', 'separated'): 2,
#  ('separated', 'by'): 3,
#  ('by', 'traditional'): 1,
#  ('traditional', 'pagii,'): 1,
#  ('pagii,', 'where'): 1,
#  ('where', 'the'): 36,
#  ('the', 'population'): 17,
#  ('population', 'remained'): 2,
#  ('remained', 'about'): 1,
#  ('about', 'the'): 18,
#  ('the', 'same'): 94,
#  ('same', 'with'): 1,
#  ('with', 'almost'): 2,
#  ('almost', 'no'): 1,
#  ('no', 'foreign'): 1,
#  ('foreign', 'settlers.'): 1,
#  ('settlers.', "Rollo's"): 1,
#  ("Rollo's", 'contingents'): 1,
#  ('contingents', 'who'): 1,
#  ('who', 'raided'): 1,
#  ('raided', 'and'): 1,
#  ('and', 'ultimately'): 3,
#  ('ultimately', 'settled'): 1,
#  ('settled', 'Normandy'): 1,
#  ('Normandy', 'and'): 2,
#  ('and', 'parts'): 4,
#  ('parts', 'of'): 31,
#  ('coast', 'included'): 1,
#  ('included', 'Danes,'): 1,
#  ('Danes,', 'Norwegians,'): 1,
#  ('Norwegians,', 'Norse–Gaels,'): 1,
#  ('Norse–Gaels,', 'Orkney'): 1,
#  ('Orkney', 'Vikings,'): 1,
#  ('Vikings,', 'possibly'): 1,
#  ('possibly', 'Swedes,'): 1,
#  ('Swedes,', 'and'): 1,
#  ('and', 'Anglo-Danes'): 1,
#  ('Anglo-Danes', 'from'): 1,
#  ('the', 'English'): 16,
#  ('English', 'Danelaw'): 1,
#  ('Danelaw', 'under'): 1,
#  ('under', 'Norse'): 1,
#  ('Norse', 'control.'): 1,
#  ('control.', 'The'): 2,
#  ('The', 'descendants'): 1,
#  ('descendants', 'of'): 6,
#  ('of', "Rollo's"): 1,
#  ("Rollo's", 'Vikings'): 1,
#  ('Vikings', 'and'): 1,
#  ('and', 'their'): 18,
#  ('their', 'Frankish'): 1,
#  ('Frankish', 'wives'): 1,
#  ('wives', 'would'): 1,
#  ('would', 'replace'): 1,
#  ('replace', 'the'): 2,
#  ('the', 'Norse'): 2,
#  ('Norse', 'religion'): 1,
#  ('religion', 'and'): 2,
#  ('and', 'Old'): 1,
#  ('Norse', 'language'): 2,
#  ('language', 'with'): 2,
#  ('with', 'Catholicism'): 1,
#  ('Catholicism', '(Christianity)'): 1,
#  ('(Christianity)', 'and'): 1,
#  ('the', 'local'): 15,
#  ('local', 'people,'): 1,
#  ('people,', 'blending'): 1,
#  ('blending', 'their'): 1,
#  ('their', 'maternal'): 1,
#  ('maternal', 'Frankish'): 1,
#  ('Frankish', 'heritage'): 1,
#  ('heritage', 'with'): 1,
#  ('with', 'Old'): 1,
#  ('Norse', 'traditions'): 1,
#  ('traditions', 'and'): 1,
#  ('and', 'customs'): 2,
#  ('customs', 'to'): 1,
#  ('to', 'synthesize'): 1,
#  ('synthesize', 'a'): 1,
#  ('a', 'unique'): 7,
#  ('unique', '"Norman"'): 1,
#  ('"Norman"', 'culture'): 1,
#  ('culture', 'in'): 1,
#  ('the', 'north'): 13,
#  ('north', 'of'): 8,
#  ('of', 'France.'): 1,
#  ('France.', 'The'): 3,
#  ('Norman', 'language'): 1,
#  ('language', 'was'): 3,
#  ('forged', 'by'): 1,
#  ('the', 'adoption'): 2,
#  ('adoption', 'of'): 7,
#  ('the', 'indigenous'): 4,
#  ('indigenous', 'langue'): 1,
#  ('langue', "d'oïl"): 1,
#  ("d'oïl", 'branch'): 1,
#  ('branch', 'of'): 9,
#  ('of', 'Romance'): 1,
#  ('Romance', 'by'): 1,
#  ('by', 'a'): 72,
#  ('a', 'Norse-speaking'): 1,
#  ('Norse-speaking', 'ruling'): 1,
#  ('ruling', 'class,'): 1,
#  ('class,', 'and'): 1,
#  ('it', 'developed'): 2,
#  ('developed', 'into'): 2,
#  ('the', 'regional'): 2,
#  ('regional', 'language'): 1,
#  ('language', 'that'): 1,
#  ('that', 'survives'): 1,
#  ('survives', 'today.'): 1,
#  ('today.', 'The'): 4,
#  ('Normans', 'thereafter'): 1,
#  ('thereafter', 'adopted'): 1,
#  ('the', 'growing'): 2,
#  ('growing', 'feudal'): 1,
#  ('feudal', 'doctrines'): 1,
#  ('doctrines', 'of'): 1,
#  ('the', 'rest'): 7,
#  ('rest', 'of'): 8,
#  ('of', 'France,'): 4,
#  ('and', 'worked'): 2,
#  ('worked', 'them'): 1,
#  ('them', 'into'): 2,
#  ('a', 'functional'): 1,
#  ('functional', 'hierarchical'): 1,
#  ('hierarchical', 'system'): 1,
#  ('system', 'in'): 2,
#  ('in', 'both'): 12,
#  ('both', 'Normandy'): 1,
#  ('in', 'England.'): 3,
#  ('England.', 'The'): 2,
#  ('The', 'new'): 4,
#  ('new', 'Norman'): 1,
#  ('Norman', 'rulers'): 1,
#  ('rulers', 'were'): 2,
#  ('were', 'culturally'): 1,
#  ('culturally', 'and'): 1,
#  ('and', 'ethnically'): 1,
#  ('ethnically', 'distinct'): 1,
#  ('distinct', 'from'): 6,
#  ('old', 'French'): 1,
#  ('French', 'aristocracy,'): 1,
#  ('aristocracy,', 'most'): 1,
#  ('most', 'of'): 35,
#  ('of', 'whom'): 6,
#  ('whom', 'traced'): 1,
#  ('traced', 'their'): 1,
#  ('their', 'lineage'): 1,
#  ('lineage', 'to'): 3,
#  ('to', 'Franks'): 1,
#  ('Franks', 'of'): 1,
#  ('the', 'Carolingian'): 1,
#  ('Carolingian', 'dynasty.'): 1,
#  ('dynasty.', 'Most'): 2,
#  ('Most', 'Norman'): 1,
#  ('Norman', 'knights'): 1,
#  ('knights', 'remained'): 1,
#  ('remained', 'poor'): 1,
#  ('poor', 'and'): 5,
#  ('and', 'land-hungry,'): 1,
#  ('land-hungry,', 'and'): 1,
#  ('and', 'by'): 19,
#  ('by', '1066'): 1,
#  ('1066', 'Normandy'): 1,
#  ('Normandy', 'had'): 1,
#  ('had', 'been'): 35,
#  ('been', 'exporting'): 1,
#  ('exporting', 'fighting'): 1,
#  ('fighting', 'horsemen'): 1,
#  ('horsemen', 'for'): 1,
#  ('for', 'more'): 4,
#  ('more', 'than'): 46,
#  ('than', 'a'): 7,
#  ('a', 'generation.'): 1,
#  ('generation.', 'Many'): 1,
#  ('Many', 'Normans'): 1,
#  ('Normans', 'of'): 2,
#  ('of', 'Italy,'): 1,
#  ('Italy,', 'France'): 1,
#  ('France', 'and'): 11,
#  ('and', 'England'): 3,
#  ('England', 'eventually'): 1,
#  ('eventually', 'served'): 1,
#  ('served', 'as'): 9,
#  ('as', 'avid'): 1,
#  ('avid', 'Crusaders'): 1,
#  ('Crusaders', 'under'): 1,
#  ('under', 'the'): 47,
#  ('the', 'Italo-Norman'): 1,
#  ('Italo-Norman', 'prince'): 1,
#  ('prince', 'Bohemund'): 1,
#  ('Bohemund', 'I'): 1,
#  ('I', 'and'): 3,
#  ('the', 'Anglo-Norman'): 2,
#  ('Anglo-Norman', 'king'): 1,
#  ('king', 'Richard'): 1,
#  ('Richard', 'the'): 2,
#  ('the', 'Lion-Heart.'): 1,
#  ('Lion-Heart.', 'Soon'): 1,
#  ('Soon', 'after'): 1,
#  ('after', 'the'): 50,
#  ('Normans', 'began'): 2,
#  ('began', 'to'): 16,
#  ('to', 'enter'): 5,
#  ('enter', 'Italy,'): 1,
#  ('Italy,', 'they'): 1,
#  ('they', 'entered'): 1,
#  ('entered', 'the'): 2,
#  ('the', 'Byzantine'): 4,
#  ('Byzantine', 'Empire'): 1,
#  ('Empire', 'and'): 4,
#  ('and', 'then'): 27,
#  ('then', 'Armenia,'): 1,
#  ('Armenia,', 'fighting'): 1,
#  ('fighting', 'against'): 1,
#  ('against', 'the'): 29,
#  ('the', 'Pechenegs,'): 1,
#  ('Pechenegs,', 'the'): 1,
#  ('the', 'Bulgars,'): 1,
#  ('Bulgars,', 'and'): 1,
#  ('and', 'especially'): 1,
#  ('especially', 'the'): 3,
#  ('the', 'Seljuk'): 1,
#  ('Seljuk', 'Turks.'): 1,
#  ('Turks.', 'Norman'): 1,
#  ('Norman', 'mercenaries'): 3,
#  ('mercenaries', 'were'): 1,
#  ('were', 'first'): 4,
#  ('first', 'encouraged'): 1,
#  ('encouraged', 'to'): 1,
#  ('to', 'come'): 2,
#  ('come', 'to'): 8,
#  ('the', 'south'): 10,
#  ('south', 'by'): 1,
#  ('the', 'Lombards'): 1,
#  ('Lombards', 'to'): 1,
#  ('to', 'act'): 1,
#  ('act', 'against'): 1,
#  ('the', 'Byzantines,'): 1,
#  ('Byzantines,', 'but'): 1,
#  ('but', 'they'): 3,
#  ('they', 'soon'): 1,
#  ('soon', 'fought'): 1,
#  ('fought', 'in'): 3,
#  ('in', 'Byzantine'): 1,
#  ('Byzantine', 'service'): 1,
#  ('service', 'in'): 1,
#  ('in', 'Sicily.'): 1,
#  ('Sicily.', 'They'): 1,
#  ('were', 'prominent'): 1,
#  ('prominent', 'alongside'): 1,
#  ('alongside', 'Varangian'): 1,
#  ('Varangian', 'and'): 1,
#  ('and', 'Lombard'): 1,
#  ('Lombard', 'contingents'): 1,
#  ('contingents', 'in'): 1,
#  ('the', 'Sicilian'): 2,
#  ('Sicilian', 'campaign'): 1,
#  ('campaign', 'of'): 3,
#  ('of', 'George'): 2,
#  ('George', 'Maniaces'): 2,
#  ('Maniaces', 'in'): 2,
#  ('in', '1038–40.'): 1,
#  ('1038–40.', 'There'): 1,
#  ('There', 'is'): 14,
#  ('is', 'debate'): 1,
#  ('debate', 'whether'): 1,
#  ('whether', 'the'): 11,
#  ('Normans', 'in'): 1,
#  ('in', 'Greek'): 2,
#  ('Greek', 'service'): 1,
#  ('service', 'actually'): 1,
#  ('actually', 'were'): 1,
#  ('were', 'from'): 2,
#  ('from', 'Norman'): 1,
#  ('Norman', 'Italy,'): 1,
#  ('Italy,', 'and'): 3,
#  ('it', 'now'): 3,
#  ('now', 'seems'): 1,
#  ('seems', 'likely'): 1,
#  ('likely', 'only'): 1,
#  ('only', 'a'): 11,
#  ('a', 'few'): 26,
#  ('few', 'came'): 1,
#  ('came', 'from'): 8,
#  ('from', 'there.'): 1,
#  ('there.', 'It'): 1,
#  ('It', 'is'): 69,
#  ('is', 'also'): 59,
#  ('also', 'unknown'): 1,
#  ('unknown', 'how'): 1,
#  ('how', 'many'): 1,
#  ('many', 'of'): 27,
#  ('the', '"Franks",'): 1,
#  ('"Franks",', 'as'): 1,
#  ('as', 'the'): 247,
#  ('the', 'Byzantines'): 5,
#  ('Byzantines', 'called'): 1,
#  ('called', 'them,'): 1,
#  ('them,', 'were'): 1,
#  ('were', 'Normans'): 1,
#  ('Normans', 'and'): 3,
#  ('and', 'not'): 12,
#  ('not', 'other'): 1,
#  ('other', 'Frenchmen.'): 1,
#  ('Frenchmen.', 'One'): 1,
#  ('One', 'of'): 22,
#  ('first', 'Norman'): 2,
#  ('mercenaries', 'to'): 1,
#  ('to', 'serve'): 9,
#  ('serve', 'as'): 12,
#  ('a', 'Byzantine'): 1,
#  ('Byzantine', 'general'): 2,
#  ('general', 'was'): 1,
#  ('was', 'Hervé'): 1,
#  ('Hervé', 'in'): 1,
#  ('the', '1050s.'): 1,
#  ('1050s.', 'By'): 1,
#  ('By', 'then'): 1,
#  ('then', 'however,'): 1,
#  ('however,', 'there'): 1,
#  ('there', 'were'): 26,
#  ('were', 'already'): 2,
#  ('already', 'Norman'): 1,
#  ('mercenaries', 'serving'): 1,
#  ('serving', 'as'): 2,
#  ('as', 'far'): 7,
#  ('far', 'away'): 1,
#  ('away', 'as'): 1,
#  ('as', 'Trebizond'): 1,
#  ('Trebizond', 'and'): 1,
#  ('and', 'Georgia.'): 1,
#  ('Georgia.', 'They'): 1,
#  ('were', 'based'): 3,
#  ('based', 'at'): 1,
#  ('at', 'Malatya'): 1,
#  ('Malatya', 'and'): 1,
#  ('and', 'Edessa,'): 1,
#  ('Edessa,', 'under'): 1,
#  ('Byzantine', 'duke'): 1,
#  ('duke', 'of'): 1,
#  ('of', 'Antioch,'): 1,
#  ('Antioch,', 'Isaac'): 1,
#  ('Isaac', 'Komnenos.'): 2,
#  ('Komnenos.', 'In'): 1,
#  ('the', '1060s,'): 1,
#  ('1060s,', 'Robert'): 1,
#  ('Robert', 'Crispin'): 1,
#  ('Crispin', 'led'): 1,
#  ('led', 'the'): 6,
#  ('of', 'Edessa'): 1,
#  ('Edessa', 'against'): 1,
#  ('the', 'Turks.'): 1,
#  ('Turks.', 'Roussel'): 1,
#  ('Roussel', 'de'): 1,
#  ('de', 'Bailleul'): 1,
#  ('Bailleul', 'even'): 1,
#  ('even', 'tried'): 1,
#  ('tried', 'to'): 4,
#  ('to', 'carve'): 2,
#  ('carve', 'out'): 2,
#  ('out', 'an'): 2,
#  ('an', 'independent'): 6,
#  ('independent', 'state'): 2,
#  ('state', 'in'): 6,
#  ('in', 'Asia'): 5,
#  ('Asia', 'Minor'): 1,
#  ('Minor', 'with'): 1,
#  ('with', 'support'): 2,
#  ('support', 'from'): 5,
#  ('local', 'population,'): 1,
#  ('population,', 'but'): 1,
#  ('but', 'he'): 2,
#  ('he', 'was'): 15,
#  ('was', 'stopped'): 2,
#  ('stopped', 'by'): 2,
#  ('general', 'Alexius'): 1,
#  ('Alexius', 'Komnenos.'): 1,
#  ('Komnenos.', 'Some'): 1,
#  ('Some', 'Normans'): 1,
#  ('Normans', 'joined'): 1,
#  ('joined', 'Turkish'): 1,
#  ('Turkish', 'forces'): 1,
#  ('forces', 'to'): 3,
#  ('to', 'aid'): 6,
#  ('aid', 'in'): 2,
#  ('the', 'destruction'): 2,
#  ('destruction', 'of'): 6,
#  ('the', 'Armenians'): 1,
#  ('Armenians', 'vassal-states'): 1,
#  ('vassal-states', 'of'): 1,
#  ('of', 'Sassoun'): 1,
#  ('Sassoun', 'and'): 1,
#  ('and', 'Taron'): 1,
#  ('Taron', 'in'): 1,
#  ('in', 'far'): 1,
#  ('far', 'eastern'): 2,
#  ('eastern', 'Anatolia.'): 1,
#  ('Anatolia.', 'Later,'): 1,
#  ('Later,', 'many'): 1,
#  ('many', 'took'): 1,
#  ('took', 'up'): 1,
#  ('up', 'service'): 1,
#  ('service', 'with'): 1,
#  ('the', 'Armenian'): 2,
#  ('Armenian', 'state'): 1,
#  ('state', 'further'): 1,
#  ('further', 'south'): 2,
#  ('south', 'in'): 2,
#  ('in', 'Cilicia'): 1,
#  ('Cilicia', 'and'): 1,
#  ('the', 'Taurus'): 1,
#  ('Taurus', 'Mountains.'): 1,
#  ('Mountains.', 'A'): 1,
#  ('A', 'Norman'): 1,
#  ('Norman', 'named'): 1,
#  ('named', 'Oursel'): 1,
#  ('Oursel', 'led'): 1,
#  ('led', 'a'): 2,
#  ('a', 'force'): 13,
#  ('force', 'of'): 11,
#  ('of', '"Franks"'): 1,
#  ('"Franks"', 'into'): 1,
#  ('the', 'upper'): 8,
#  ('upper', 'Euphrates'): 1,
#  ('Euphrates', 'valley'): 1,
#  ('valley', 'in'): 1,
#  ('in', 'northern'): 3,
#  ('northern', 'Syria.'): 1,
#  ('Syria.', 'From'): 1,
#  ('From', '1073'): 1,
#  ('1073', 'to'): 1,
#  ('to', '1074,'): 1,
#  ('1074,', '8,000'): 1,
#  ('8,000', 'of'): 1,
#  ('the', '20,000'): 1,
#  ('20,000', 'troops'): 1,
#  ('troops', 'of'): 1,
#  ('Armenian', 'general'): 1,
#  ('general', 'Philaretus'): 1,
#  ('Philaretus', 'Brachamius'): 1,
#  ('Brachamius', 'were'): 1,
#  ('were', 'Normans—formerly'): 1,
#  ('Normans—formerly', 'of'): 1,
#  ('of', 'Oursel—led'): 1,
#  ('Oursel—led', 'by'): 1,
#  ('by', 'Raimbaud.'): 1,
#  ('Raimbaud.', 'They'): 1,
#  ('They', 'even'): 1,
#  ('even', 'lent'): 1,
#  ('lent', 'their'): 1,
#  ('their', 'ethnicity'): 1,
#  ('ethnicity', 'to'): 1,
#  ('the', 'name'): 22,
#  ('name', 'of'): 11,
#  ('their', 'castle:'): 1,
#  ('castle:', 'Afranji,'): 1,
#  ('Afranji,', 'meaning'): 1,
#  ...}

# %%
word = 'many cat'

# %%
from google_ngram_downloader import readline_google_store
 
count = 0
fname, url, records = next(readline_google_store(ngram_len=1, indices=word[0]))
 
try:
	record = next(records)
 
	while record.ngram != word:
		record = next(records)
 
	while record.ngram == word:
		count = count + record.match_count
		record = next(records)
		
except StopIteration:
	pass

# %%
#read json file
with open('dev-v2.0.json') as json_data:
    content = json.load(json_data)
    json_data.close()

#parse json into a list of paragraphs
para = []
for data in content['data']:
    for paragraphs in data['paragraphs']:
        para.append(paragraphs['context'])

# #parse paragraph into list of sentences
# def parse_sentences(paragraph): 
#     sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
#     sentences = sent_detector.tokenize(paragraph.strip())
#     return sentences

# squad_sentences = []
# for p in para:
#     squad_sentences += parse_sentences(p)

# %%
# for s in squad_sentences:
#      if 'CARDINAL' in get_entity(s) or 'QUANTITY' in get_entity(s):
#             print(s)

# %%
nlp = spacy.load("en_core_web_lg")

# %%
def countable_noun(noun):
    url = 'https://books.google.com/ngrams/graph?content=many+' + noun + '%2C+much+' + noun + '&year_start=1800&year_end=2000'
    response = urllib.request.urlopen(url)
    html = response.read().decode('utf-8')

    try:
        many_data = json.loads(re.search('\{"ngram": "many ' + noun + '".*?\}', html).group(0))['timeseries']
        many = sum(many_data) / float(len(many_data))
    except:
        many = 0.0
    try:
        much_data = json.loads(re.search('\{"ngram": "much ' + noun + '".*?\}', html).group(0))['timeseries']
        much = sum(much_data) / float(len(much_data))
    except:
        much = 0.0
    if many > much:
        return True
    return False

# %%
def get_nsubj(sentence):
    doc = nlp(sentence)
    for chunk in doc.noun_chunks:
        if chunk.root.dep_ == 'nsubj':
            return chunk.text
    return ''

def get_ROOT(sentence):
    doc = nlp(sentence)
    for token in doc:
        if token.dep_ == 'ROOT':
            return token.text, token.lemma_,token.tag_
    return ''

def get_entity(sentences):
    entity = []
    doc = nlp(sentences)
    for ent in doc.ents:
        entity.append( ent.label_)
    return entity


def get_namechunks(sentence):
    chunks = {}
    doc = nlp(sentence)
    for chunk in doc.noun_chunks:
        chunks[chunk.text] = chunk.root.text
        #chunks.append(chunk.text)
    return chunks

def get_tense(verb_t):
    # the verb is present third person singular
    if verb_t == 'VBZ':
        result = " does "
    elif verb_t in ['VBP', 'VBG', 'VB']:
        # tense = "present"
        result = " do " 
    elif verb_t in ['VBD', 'VBN']:
        # tense = "past"
        result = " did "
    else:
        result = ' does '
    return result

def get_pps(sentence):
    doc = nlp(sentence)
    pps = []
    for token in doc:
        # Try this with other parts of speech for different subtrees.
        if token.pos_ == 'ADP':
            pp = ' '.join([tok.orth_ for tok in token.subtree])
            pps.append(pp)
    return pps

# %%
def gen_question_type1(sentence,obj):
    root = get_ROOT(sentence)
    subj =get_nsubj(sentence)
    prep = ''
    loc = ''
    if len(get_pps(sentence)) > 0:
        for pp in get_pps(sentence):
            if pp.upper().split()[0] in ['DURING','IN','WHITIN','FROM','UNTIL'] and len(get_entity(pp))>0:
                if 'DATE' in get_entity(pp) or 'TIME' in get_entity(pp): #'CARDINAL' in get_entity(pp) or
                    prep = pp
            if (pp.upper().split()[0] == 'IN' or pp.upper().split()[0] == 'ON' or pp.upper().split()[0] == 'AT') and len(get_entity(pp))>0:
                if get_entity(pp)[0] in ['GPE','FAC','ORG','LOC']:
                    loc = pp
                    
    if subj != None:
        return "How many "+obj+get_tense(root[2])+subj+" "+root[1].lower()+' '+prep.lower()+' '+loc+'?'
    else:
        return "How many "+obj+" were "+root[0].lower()+' '+prep.lower()+' '+loc+'?'

# %%
def gen_question_type2(sentence,obj):
    prep = ''
    if len(get_pps(sentence)) > 0:
        for pp in get_pps(sentence):
            if pp.upper().split()[0] == 'IN' and len(get_entity(pp))>0:
                if get_entity(pp)[0] in ['GPE','FAC','ORG','LOC']:
                    prep = pp

    return "How many "+obj+" are there "+prep.lower()+'?'

# %%
def gen_question_type3(sentence,obj):
    root = get_ROOT(sentence)
    subj =get_nsubj(sentence)
    if obj == '' and root == '' :
        return ''
    if obj == '' and subj == '' :
        return ''
    prep = ''
    loc = ''
    if len(get_pps(sentence)) > 0:
        for pp in get_pps(sentence):
            if pp.upper().split()[0] in ['DURING','IN','WHITIN','FROM','UNTIL'] and len(get_entity(pp))>0:
                if 'CARDINAL' in get_entity(pp) or 'DATE' in get_entity(pp) or 'TIME' in get_entity(pp):
                    prep = pp
            if (pp.upper().split()[0] == 'IN' or pp.upper().split()[0] == 'ON') and len(get_entity(pp))>0:
                if get_entity(pp)[0] in ['GPE','FAC','ORG','LOC']:
                    loc = pp

    return "How much "+obj+get_tense(root[2])+subj+" "+root[1].lower()+' '+prep.lower()+' '+loc+'?'

# %%
def select_question(sentence):
    obj = ''
    for chunk in get_namechunks(sentence).keys():
        if 'CARDINAL' in get_entity(chunk) or 'QUANTITY' in get_entity(chunk):
            obj = get_namechunks(sentence)[chunk]

    if obj == '':
        return gen_question_type3(sentence, obj)
    
    if countable_noun(obj):
        if 'there' in sentence.lower():
            return gen_question_type2(sentence, obj)
        else:
            return gen_question_type1(sentence, obj)
    else:
        return gen_question_type3(sentence, obj)

# %%
select_question('The term itself was coined by eighteenth-century historians and the distinction between the Old Kingdom and the Early Dynastic Period is not one which would have been recognized by Ancient Egyptians.')
# Out:
# ''

# %%
def open_html(filename):
    soup = BeautifulSoup(open(filename,encoding='utf-8'), "html.parser")
    page = soup.find_all('p')
    paragraphs = ''
    for p in page:
        paragraphs += p.getText()
    return paragraphs

def parse_sentences(paragraph): 
    sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
    sentences = sent_detector.tokenize(paragraph.strip())
    return sentences

# %%
paragraphs = open_html("a2.htm")

# %%
for sentence in parse_sentences(paragraphs):
    #print(sentence)
    print(select_question(sentence))
    time.sleep(5)
# Out:
# How much  does The Middle Kingdom be from the reunification of egypt under the impulse of mentuhotep ii of the eleventh dynasty to the end of the twelfth dynasty in the history of ancient Egypt between circa 2050 BC and 1710 BC?
# How many BC do Some scholars include until merneferre ay c. 1700 bc , last king of this dynasty to be attested in both upper and lower egypt in both Upper and Lower Egypt?
# How many phases did Osiris become from thebes and the 12th dynasty ?
# How many dynasties did two rival dynasties fight  in Egyptology?
# How much  did The Theban 11th Dynasty rule  ?
#
# How many B.C. did The struggle be  ?
# How much  did he take during mentuhotep ii 's fourteenth regnal year on Herakleopolis , which met little resistance?
# How much  did Mentuhotep begin  ?
#
# How much  did He restore  ?
# How much  did he restore  in the eastern Delta region?
# How much  did He send  on the Red Sea?
#
# How much  does The Turin Papyrus claim  ?
#
# How much  did The leader be  ?
# How much  do certain circumstantial evidence point  ?
# How much  did Inscriptions leave  ?
# How many ships does Khnumhotep I claim  ?
# How many claimants did Donald Redford suggest  ?
# How much  does What be from the 12th dynasty onwards ?
#
# How much  did the Middle Kingdom be during the 11th dynasty in the Delta region , which had not received as much attention as upper Egypt during the 11th Dynasty?
# How much  did he strengthen  in the East Delta region?
# How much  did I build  ?
# How much  does The location be  ?
# How much  did Amenemhet bolster  ?
# How much  does the Prophecy date  ?
# How much  did the governors gain  ?
# How much  did Their posts become  ?
# How much  did Amenemhet require  ?
# How much  did Egypt give in his 20th regnal year ?
#
# How much  did Senusret rush  ?
# How much  did he continue  ?
# How much  did Egyptian armies push  ?
# How much  did he consolidate  ?
# How much  did Senusret appoint in his 43rd regnal year ?
# How much  do descriptions be  ?
# How much  did Amenemhet send  ?
# How much  do It appear  ?
# How much  does Another expedition date  ?
# How much  did he appoint in his 33rd regnal year ?
# How much  does Senusret appear  ?
#
# How much  did Senusret place  ?
# How much  did He reign  ?
# How much  did His son succeed  ?
#
# How much  did He use in his sixth , eighth , tenth , and sixteenth years in Nubia?
# How much  did Senusret build  ?
# How much  did the Egyptians charge  ?
# How much  did they allow  ?
# How many campaign did Senusret send in his 19th year ?
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-73-b793f482708e> in <module>()
#       1 for sentence in parse_sentences(paragraphs):
#       2     #print(sentence)
# ----> 3     print(select_question(sentence))
#       4     time.sleep(5)
#
# <ipython-input-52-75b6b35e699d> in select_question(sentence)
#       8         return gen_question_type3(sentence, obj)
#       9
# ---> 10     if countable_noun(obj):
#      11         if 'there' in sentence.lower():
#      12             return gen_question_type2(sentence, obj)
#
# <ipython-input-5-9009b3252741> in countable_noun(noun)
#       1 def countable_noun(noun):
#       2     url = 'https://books.google.com/ngrams/graph?content=many+' + noun + '%2C+much+' + noun + '&year_start=1800&year_end=2000'
# ----> 3     response = urllib.request.urlopen(url)
#       4     html = response.read().decode('utf-8')
#       5
#
# ~/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     744                 len(visited) >= self.max_redirections):
#     745                 raise HTTPError(req.full_url, code,
# --> 746                                 self.inf_msg + msg, headers, fp)
#     747         else:
#     748             visited = new.redirect_dict = req.redirect_dict = {}
#
# HTTPError: HTTP Error 302: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Found

# %%
get_ROOT('campaign')
# Out:
# ('campaign', 'campaign', 'NN')

# %%
import pattern3

# %%
import pluralize, singularize

# %%
pattern3.pluralize('child')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-469c05c9383b> in <module>()
# ----> 1 pattern3.pluralize('child')
#
# AttributeError: module 'pattern3' has no attribute 'pluralize'
